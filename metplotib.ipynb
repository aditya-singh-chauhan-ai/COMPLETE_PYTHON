# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
# Corrected the typo in 'matplotlib' (was missing the 'l')

# %%
# !pip install matplotlib

# %%
import seaborn as sns

# %%
# !pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x_val=[0,1,2]
y_val=[3,5,9]

# %%
plt.plot(x_val,y_val)

# %%
read_Dataframe(employee_salaries.csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 read_Dataframe(employee_salaries.csv)
#
# NameError: name 'read_Dataframe' is not defined

# %%
# Import pandas library first
import pandas as pd

# Use the correct function name: read_csv instead of read_Dataframe
# Also, wrap the filename in quotes as it's a string
data = pd.read_csv("employee_salaries.csv")

# %%
data.head()
# Out:
#    Years_of_Experience       Salary
# 0             1.000000  40000.00000
# 1             2.257942  65979.42119
# 2             2.450875  67253.57549
# 3             2.498713  67342.43510
# 4             2.613729  70532.20448

# %%
x=[1,2,3,4,5]
y=[10,20,22,29,35]
plt.plot(x,y)
plt.show()

# %%
x=['Mon','TUE','WED','THU','FRI']
y=[10,15,7,20,12]
plt.plot(x,y)

plt.title('Bakery sales this weak:')
plt.xlabel('days')
plt.ylabel('sales')
plt.show()

# %%
#plt.plot(x,y, color='color name', linestyle='line_style',linewidth=value,marker='marker symbol',label='laabel name')
#plt.xlabel('text')
# plt.ylabel('text')
#plt.title('text')
# plt.grid('text',line color or anything)
# plt.legend(loc=upper left, lower right)
# plt.xlim(enter ranges)
# plt.ylim(enter ranges)
# plt.xticks('give original labeling', 'meaningful labeling')
# plt.yticks('give original labeling', 'meaningful labeling')
months=[1,2,3,4]
sales=[1000,1500,1200,1800]
plt.plot(months, sales, color='blue', linestyle='--',linewidth = 2, marker = 0, label='2025 sales data')
plt.xlabel('months')
plt.ylabel('sales')
plt.title('mothly data')
plt.legend()
plt.xlim(1,4)
plt.ylim(0,2000)
plt.xticks([1,2,3,4],['M1','M2','M3','M4'])
plt.grid(color='red',linestyle=':',linewidth=2)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#plt.bar(x, height,color='color name',width=value,label='label name')
product= ['A', 'B', 'C', 'D']
sales=[1000,1500,800,1200]
plt.bar(product, sales, color='orange', label='sales 2025')
plt.xlabel('Product')
plt.ylabel('Sales')
plt.title('Product Sales Comparison')
plt.legend()
plt.show()

# %%
regions=['North', 'South', 'East', 'West']
revenue=[3000,2000,1500,1000]
plt.pie(revenue, labels=regions, autopct='%1.1f%%', colors=('gold', 'skyblue', 'orange', 'pink'))
plt.title('Revune Contribution by Regions')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
scores=[12,35,65,45,65,95,85,15,35,75,65,25,32,35,12,46,36,95]
plt.hist(scores, bins=5, color='purple', edgecolor='black')
plt.xlabel('Score range')
plt.ylabel('Number of Students')
plt.title('Score Distributin of Students')

plt.show()

# %%
# plt.scatter(x,y,color='color name',marker='marker style',label='label name')
hoursr_studied=[1,2,3,4,5,6,7,8]
exam_scores=[50,55,60,65,70,75,80,85]
plt.scatter(hoursr_studied, exam_scores, color='Red', marker= 'o', label='Student Data')
plt.xlabel('Hours studied')
plt.ylabel('Exam scores')
plt.title('Relationship with time and score')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.scatter([1,2,3],[50,60,70], color='Red', marker= 'o', label='Class A')
plt.scatter([1,2,3],[40,50,52], color='Green', marker= 'o', label='Class A')
plt.xlabel('Hours studied')
plt.ylabel('Exam scores')
plt.title('Relationship with time and score')
plt.legend()
plt.grid(True)
plt.show()

# %%
x=[1,2,3,4]
y=[10,20,35,49]
plt.subplot(1,2,1)    #1row, 2column, 1st subplot 
plt.plot(x,y)
plt.subplot(1,2,2) #1row, 2column, 2nd subplot 
plt.bar(x,y)
plt.title('Bar chart')
#plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=[1,2,3,4]
y=[10,20,35,49]
fig, ax= plt.subplots(1,2, figsize = (10,5))
ax[0].plot(x,y)
ax[0].set_title('Line plot')
ax[1].bar(x,y)
ax[1].set_title('Bar chart')
fig.suptitle('cc')
plt.tight_layout()
plt.show()

# %%
x=[1,2,3,4]
y=[10,20,35,49]
plt.plot(x,y,color='blue',marker='o')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Simple Line Plot')
plt.savefig('line_plot.png', dpi=300, bbox_inches='tight')
plt.show()
